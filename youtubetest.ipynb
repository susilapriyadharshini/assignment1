# %%
from googleapiclient.discovery import build
import pymongo
import psycopg2

# %%
    #API key connection
def Api_connect():
            Api_Id="AIzaSyAWpZvYqvEMv3NPqa6negi6HHGRKcmFfDI"

            api_service_name="youtube"
            api_version="v3"

            youtube=build(api_service_name,api_version,developerKey=Api_Id)

            return youtube

youtube=Api_connect()

# %%
#get channels information
def get_Channel_info(Channel_id):
    request=youtube.channels().list(
                    part="snippet,ContentDetails,statistics",
                    id=Channel_id
    )
    response=request.execute()

    for i in response['items']:
        data=dict(Channel_Name=i["snippet"]["title"],
                Channel_Id=i["id"],
                Subscribers=i['statistics']['subscriberCount'],
                Views=i["statistics"]["viewCount"],
                Total_videos=i["statistics"]["videoCount"],
                channel_Description=i["snippet"]["description"],
                playlist_Id=i["contentDetails"]["relatedPlaylists"]["uploads"])
        return data

# %%
channel_details=get_Channel_info("UC5cY198GU1MQMIPJgMkCJ_Q")

# %%
channel_details
# Out:
# {'Channel_Name': 'Mr. GK',
#  'Channel_Id': 'UC5cY198GU1MQMIPJgMkCJ_Q',
#  'Subscribers': '1360000',
#  'Views': '188944410',
#  'Total_videos': '477',
#  'channel_Description': 'Please contact me thru my mail id given below.\n\nFollow us on my social media:\nWhatsApp: https://whatsapp.com/channel/0029VaA23u5IHphLuhO3LM01\nYoutube: https://www.youtube.com/MrGKTamil\nFacebook: https://www.facebook.com/MrGKTamil\nTwitter: https://twitter.com/Mr_GK_Tamil\nInstagram: http://instagram.com/Mr_Gk_Tamil\nTelegram: https://t.me/MrGkGroup\n',
#  'playlist_Id': 'UU5cY198GU1MQMIPJgMkCJ_Q'}

# %%
#get video ids
def get_videos_ids(channel_id):
    Video_ids=[]

    response=youtube.channels().list(id=channel_id,
                                    part='contentDetails').execute()
    playlist_Id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']


    next_Page_token=None
    while True:

        response1=youtube.playlistItems().list(
                                            part='snippet',
                                            playlistId=playlist_Id,
                                            maxResults=50,
                                            pageToken=next_Page_token).execute()
        for i in range(len(response1['items'])):
            Video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
        next_Page_token=response1.get('nextPageToken')

        if next_Page_token is None:
                break
    return Video_ids

# %%
video_Ids=get_videos_ids('UC5cY198GU1MQMIPJgMkCJ_Q')

# %%
video_Ids
# Out:
# ['e4t2WAhGr08',
#  'jRDDvpkKQAk',
#  'hua0FANT_-E',
#  'OAJbMwp0ruU',
#  'K1WVzZmDEoo',
#  'UnqoTiWXUBo',
#  'PuL_CP_Vr5s',
#  'DHMv_7WNSl4',
#  'Dp1hC-p_do0',
#  '2jXqIfic1U8',
#  'lhiI5slH81U',
#  'OrqdeC6_OnA',
#  '9ROJBtbni_g',
#  'r9xv8ZsCpT4',
#  'c3peKw--wmE',
#  'ooV9WAxtTU0',
#  'QKmnSh0XE1o',
#  'Lsbexi-6KRw',
#  'hP38eGcmX6c',
#  'IND1IkA-M-o',
#  'LMuAa43tD2w',
#  'LGEVX7UBZfI',
#  '1fHl6m54w9Q',
#  'UI3HKcPda9g',
#  'sS5mbtg87JM',
#  'PmGQ1n-9Pqs',
#  'i6JREnRGAKA',
#  'OS8tc7UqoH8',
#  'lpaR7sKCAdA',
#  'gz-RIZXvFNE',
#  'Vm6MoiKL_FA',
#  '3Sxl3YUMOAs',
#  'DL_vHEiG6UA',
#  'Ar3gbUp0mZY',
#  'w9igFZ3EXxU',
#  'av1l4ilAmn4',
#  'eo21a38SJY8',
#  'aEZNo7DgKjs',
#  'F1H7rOV--Ig',
#  'Y7CRGOTfTpQ',
#  'E09EALx1E98',
#  'RXRQWWYfoH4',
#  'P6by2MQCVGo',
#  '-_0cDXrzFFU',
#  'Xsv701Y3WrA',
#  'AEmxj3IB4gc',
#  'xSxeW3q8jPU',
#  '7UZrdyenkzw',
#  'TfsyzFKHAF4',
#  'ZGkXZ5RKB38',
#  'ynQWJYs_P6M',
#  'pfrz0aIdpVk',
#  'cv4IESR6RIY',
#  'wjXDFz4fSXs',
#  'UJ7GV9laatI',
#  'jxkxW3gazUY',
#  'hEcJBZ7Bbtw',
#  'mf2JaqjWcuU',
#  'EnYhN_d2zgU',
#  'Faa_ti10n1o',
#  'HbKO4RiON3g',
#  '0gn8Uht_I9s',
#  'my_77tHgFj8',
#  'pM5MUCBBopo',
#  'eHVCRepERlA',
#  'sEiqA63acSU',
#  'vCHAXXcD7Vk',
#  '-y2PCb3kTg4',
#  'Qelj5G-PHE0',
#  'gml0mQEhFv8',
#  'ydGLqqgAcYo',
#  'QYTko-gZ_d8',
#  'IGe7Ma7uBOE',
#  'Fk4sVR1jbT4',
#  'l1kcU7xrooM',
#  'ImHakmL25Oo',
#  't6TtAw91c3Q',
#  'J1y2faphuNc',
#  'qKAhkbUnXC8',
#  'ykD5wvngnlw',
#  '3WCDd-oRkDU',
#  '9F4ngDMx0KE',
#  'ucF0fKNMIWo',
#  'GdANVP3nZ44',
#  'Y1214zndIYc',
#  '8EubWDMLh5E',
#  'wOe6UleLldw',
#  '0T6nDXhjdIg',
#  'R0MqUZXK0YY',
#  '6bFEo12lDUI',
#  'nwww5AGlcm8',
#  'cSBODBnklE8',
#  'tkkW8Fim_-E',
#  'O6esI4tVFgA',
#  'QbtiSF3I3vE',
#  'Zs96fOzaesE',
#  'fXRGKtBQc8o',
#  'frhgd3bKxC4',
#  'OYfnL1An0Es',
#  '3aSbwokiXU8',
#  'yuLU15seGtM',
#  '2GWU-j--xjs',
#  'l5EUm8VvHiQ',
#  'r77bNXgrsVM',
#  '70Wzz-DGs_k',
#  'LkUkkILzQHo',
#  'uccTdEQmCmw',
#  'mJDIkRALYlQ',
#  'km0h5HggVvc',
#  'SRDWFqsr_PY',
#  'Jo3PErElJ6k',
#  'GeXuyIIr_6c',
#  '4DSFTtFXo0c',
#  'U2tev_CSR3A',
#  'QqqsExmJfhw',
#  'tkVH7_S3CvY',
#  'jlke3WEoMB8',
#  'aGJap845iAc',
#  'vJEoU14Y4M0',
#  'v4BzvyDT4bA',
#  'AZhoKgMf_og',
#  'ThvCWBplDbM',
#  'iJy5-fRJtFM',
#  'IdLoBjXChtk',
#  'TXcO9Yt_f-I',
#  'RYltu_N-6A8',
#  '8_F3s_tSzBM',
#  'VEQNvVdf7e4',
#  'HhYYdVX8EZw',
#  'TPlol6PqJ2Q',
#  'DrC4Nje1yTI',
#  'dmjXz50XEgc',
#  '6K0rScPDeDk',
#  'c0bZDiTpJiE',
#  'B8LycujzUwk',
#  'Z-K3nxHHgdE',
#  'wXGGnAha2K8',
#  'q1D4gg4DZEw',
#  'cd9HeGmpz9Y',
#  'pCcUjdb3heA',
#  'kCMjVEDzCwk',
#  'AsFDxy19ybA',
#  'v6_V66QdSCA',
#  '_QdkcS0v36k',
#  'B6cOg78047w',
#  '0qdEBeqqTVE',
#  'JoPFFz1lFWM',
#  '5FFNBLr0NYI',
#  'dl5zhPaPjj8',
#  'AJDAd__kJsI',
#  'dAJd_n23EuI',
#  'C7nowyxWbTM',
#  'r4k2szmiLAE',
#  'R-lKljug9vM',
#  'Ak8UZQZR6QE',
#  'ctv_VPdu8AI',
#  '76q4eDs3eRo',
#  'FNhvfIeDOio',
#  'ieiBvTzD1bY',
#  'GPWuzhi6SlE',
#  'uSlu_wZAOz4',
#  'Oj1U6ed8xDQ',
#  'SvpFIapoq-k',
#  'sS5jb5k0fu0',
#  'LxxMUbp9Tp0',
#  'he2Ep8WO9R0',
#  'cZ5T3dv6Zgw',
#  'gtPiO0xxtfI',
#  'y_soTrzTMTk',
#  'it3p6oBLhVE',
#  'Z7WF0xHhe4o',
#  'peSFR3A_zU8',
#  'wEVs2dl1Bs8',
#  'zbu6p5EROs4',
#  'O6eDW1NRm2Q',
#  'IvDlwDzbSPk',
#  'r9btw1Nn5yY',
#  '88wqChGF5SU',
#  'Bt6UDH7Gtho',
#  'Be83FPugCZ8',
#  '68btgsNJ9fM',
#  'hilD8X_RA8Q',
#  '32uvRGOvUvc',
#  'Eu19oRQeGM0',
#  '9pXDdiC_FJ0',
#  'PQXShsdeNF8',
#  '3DKMFH00zyc',
#  'SOnyg-ac-dM',
#  '6xfc3ybbx1Y',
#  'BjRcSbwe9xI',
#  '2kp8_bn2sn8',
#  'ilAITLjRUJ0',
#  'puVOCOkUXB0',
#  'rvM55dO23qc',
#  'sFmfAiZqWkM',
#  'qeDj6B3Jjfk',
#  'FkwhpbWPQbY',
#  'S2XFzSCY01o',
#  'vINgnw8hwXo',
#  'OPiljcYFx0o',
#  '0cum_ZUmdug',
#  'kcxaHL7bFo4',
#  't9sjtrKqcCY',
#  'b76_hZi-TkA',
#  'lKEMZCC7aQI',
#  '4OKejU30vRo',
#  '6IzbaaB_a50',
#  'FWaECcflIrM',
#  '_23-ZCGXeBc',
#  'C3QGSjdQqTs',
#  'UlCb1uhtNzs',
#  'ntWBF-ojmhk',
#  'ln9QHMgZMaM',
#  'uSQ66RehOI4',
#  'pYxQVNHFej0',
#  'Zjk5yvBw1-M',
#  'JEzomm_gTSw',
#  'OGpYJpzgaG8',
#  '4xbPgGcTHyw',
#  'jXTT31rUqcM',
#  'TjFefjz2kHk',
#  'PH54RrD-4OA',
#  'yOaWdxscO7g',
#  '0KnbPmqkbrI',
#  'UVvVVfGoH18',
#  'YMjTAjhMR-k',
#  'xeH5pRpd4DA',
#  'GFEJWdoaBhM',
#  'njm_YJyj5Tg',
#  'Ym8WEiBo1VI',
#  'Cf4yGGhndZI',
#  '4-LlZ93IkkI',
#  'ehjYIj8CuQU',
#  'mIl0eoUK6X8',
#  '4_j1A8nz7RQ',
#  'JYi2_4rwXpw',
#  'fRBaDXGwBco',
#  '4ZcG1mFpu5k',
#  'A-5W5UhIOHQ',
#  'xbHQ2Wd8SCU',
#  'jPeduPjByfk',
#  'vQsMIJDQdIw',
#  '92Z9az6u3Dw',
#  'P-kvLQDO82s',
#  'IQy7LFqb3UA',
#  'bWQJGa8y33A',
#  'P-2fOxuE0VE',
#  'Mluw4kEZPUE',
#  'LSdpp8QR1qk',
#  'LbYW6MDnuQY',
#  'TXEcIzVv7v8',
#  'xGGiKVoKWVo',
#  'yGBrHpF28go',
#  'kIH3RfkXYI4',
#  'EmU18Q79lPs',
#  'iPakHtvn07o',
#  'OKJkTx9Z-6w',
#  'nzwpGVg2D5Q',
#  'tkT7MHpdBo0',
#  'lON_z-Uhp-o',
#  '9VroBCfFSxI',
#  'fIqWQUTsmeY',
#  '9-FCy3OJpzM',
#  '4GXGBc5mxCk',
#  'rk5xy0zbXaI',
#  'ExgZaLz1Q3I',
#  '_7uorqQmvV0',
#  '6IMPBbDYlaQ',
#  'NeHPTpf3xqQ',
#  'ckgv6Iaufuc',
#  'Mr1SA1Obcy8',
#  '6uNQdrxl4vA',
#  'pHhemIT3Wzo',
#  'NmrA9sDN7Lw',
#  'Mm2C9f42_es',
#  'MDYgLQliD_4',
#  'pSLddCa3WYw',
#  'FTczMnkj5Mk',
#  'bL09SBjs8DU',
#  'iAoECgigEp8',
#  'pS_hgi0ih04',
#  'SJlbqD84ydY',
#  'TtovN1SAYgA',
#  'vDnrmK7ybZk',
#  'rtt8gao_S6M',
#  '1Mga6uAg8F4',
#  '6oFiZ4k8GOg',
#  'gD8dWhET7IM',
#  'WCir-6ZhGQw',
#  'd0-V3U-OWyg',
#  'DX2lJW6DhXQ',
#  'QVy_SgMwpZc',
#  'YlmIljcKoRk',
#  'zxcOHUfvzSs',
#  'FnvOtCI4R4A',
#  'gcbye_9bxrw',
#  'wJZCKjmZVxM',
#  'E2bpkEXuOJ0',
#  '7OZ8m_NBQR4',
#  'Wi-DYwY6Bg0',
#  'FNfkm4gyqqE',
#  'f98UnomrXqw',
#  'wKuvfrEKtvA',
#  'qfQ_ebkK06k',
#  'kJ_EZYyR4GE',
#  'd7HG0mksUGk',
#  'ShRtRvtxXQo',
#  'V2PjDBzyxqg',
#  '5rOCgRkEsyQ',
#  '8L_-B1hHl0A',
#  'DQOux8X0ERQ',
#  'k_0krL10uS0',
#  'cipoF7BhipI',
#  'n06bFk4_9Us',
#  'VGQdVN5z5Ac',
#  'PlA3w3d7Q-g',
#  'm7YU4xZiwDg',
#  'su4-s4yASjI',
#  'StBRkOXYmqs',
#  'knmqSmulIQM',
#  'FbIibPTZMM4',
#  'EvpD3T80vo8',
#  'xlzALf674mk',
#  'MJ5Fj6mVDjA',
#  'sosTXcHYtWc',
#  '-Stk-Ha-n7c',
#  'eatWxAzQ7uE',
#  '9hCGAKfolqg',
#  'B0emxcB205Y',
#  '0gSj2DyAOjE',
#  '4Ow1hbXLqSQ',
#  'Rg_RwHq6_iw',
#  'LlzhRvSAIMc',
#  'Isp8YQ5_tG4',
#  'Z5wqSIMVT2U',
#  'ZSaTnAjWdvs',
#  'arXlsOsSgmk',
#  'bg1_QsdRcvM',
#  'aA0ENf5X7l8',
#  'X0024YnObUs',
#  'N97653MBlmM',
#  'S9fNbxiLG2s',
#  'qWPEGajVSCA',
#  '5s3pKdgYf5I',
#  'ZunhAUxjTXQ',
#  'AndT768Qx00',
#  'hopK5-ND3Q4',
#  'nl26EdU2Mj0',
#  '7s26aOtcJwM',
#  'Whf3p5zOU-c',
#  'CPkjZYflq90',
#  'jc7MqhxK7BY',
#  '91aYWK0dEg4',
#  'X-ijZcbC_RE',
#  'FBhqDhOxb-0',
#  'RfVhTJ61-d0',
#  '-QTQmR7uA_4',
#  'og8d9jJJvrU',
#  '4-6zBotsi-s',
#  '2y94W6oacRM',
#  'WfCOXC-F8Eo',
#  'L1UVwf8KlH4',
#  'PNwW2w2rhO4',
#  'THtT4bJJueg',
#  'TOw5benzokE',
#  'dYUiZKteQHU',
#  'lyIHDehf5LE',
#  'kphFoHoqxqg',
#  '4znVu0JDjkE',
#  'T-tVhNfNlE4',
#  'eQSNznbOEhE',
#  'Zxpigk36uqs',
#  '4kKn0TDpF_o',
#  '0TS6bZXuv8A',
#  'qOKbSF6_ETQ',
#  'KVji1ms5u7E',
#  '3G-1o4_v7JI',
#  'nNoWZQmec50',
#  '0_AXUyU6CCc',
#  '0FRJ_Oxx2jY',
#  'lAMr2-BZLk4',
#  '_3TSRdrCIu8',
#  'XTVNsqDuCRQ',
#  'UlJjPEAbUt4',
#  'jKZ_3LUHzF4',
#  'F296wKKrGdw',
#  'wsRmWkCFeGU',
#  'WzV4FBeHxm8',
#  'aDOtL62N5c4',
#  'ND1NkHMLL40',
#  'zWOR52DOdPI',
#  'dZQuWBMKq4U',
#  'orDwSn2eWVU',
#  'xfeK_KoYVc8',
#  '0bSmyaBRQgY',
#  'BqW52_wnNdQ',
#  'azWOvdLIpOs',
#  '6iLYJYgEXJg',
#  'asFr4PvIOSo',
#  'x92uBHL1l34',
#  'RJ-A3x74K7E',
#  'a6h8oyEIESc',
#  'sdRt8KREW5c',
#  'oAvZkReSpNQ',
#  'eOaJ7v1CGVc',
#  '0d0SsgmwZsc',
#  'LxYPE8qLiGo',
#  'COu0YEyrmv8',
#  'oXcZXEdycuM',
#  'GJWbC1U8-7c',
#  'I4Hi760tYl0',
#  'dpWCFZoyjcg',
#  'GROHKep4vNE',
#  'wWgmVqRRtpE',
#  'oBfeKjYQTu4',
#  '__LMopRry6w',
#  'A6E33cWPJy0',
#  'nWB_NQWTUIc',
#  '3FoEs4T4NtA',
#  'IGHEa3TCfgU',
#  'b-vEgomWzl8',
#  '_KhINLMk7Tk',
#  '7c0TLZTA9LA',
#  'eE1GQxnX80k',
#  'zIzEVrNiHBs',
#  '1mL_8tNXU4I',
#  'yFuLFhJxp28',
#  'fSaREGRiFIw',
#  'pW37jJcy-N8',
#  'tsLBmrs_lj8',
#  'aCwWi8NKBpM',
#  'M4jTS4l61fI',
#  'bQKIir3Njhs',
#  'KhxP-Tydg6A',
#  'swkauxcT72U',
#  'DWtxBQbka4g',
#  '7itPvfuaT6A',
#  'hRZirXr_J9Q',
#  'ZDam09HoBl8',
#  'IZK6cnJ8Lts',
#  '1whnbD2re1E',
#  'QHppz7heeD4',
#  'vIhRedn3EWw',
#  'vMYKUB9a8Sk',
#  'tA4ATmIqo_k',
#  '6IWAkmXa5RU',
#  'ABonH40YFPc',
#  '5RxgMz0b_84',
#  '8Pam1a8tFhY',
#  'lyCy0NEeuNE',
#  '8kCtUDckGZ8',
#  '40D5QQfw628',
#  'QI30smnGzy8',
#  'utT9LFUteF8',
#  '-FYFYXTPvXU',
#  'bfDH_wfna3w',
#  'Fdl7jsW1ahU',
#  'IjKcmx9crMA',
#  'tgR8i9d9XNY',
#  'ufUWekmQ9iQ',
#  'PefYPTbuuSg',
#  'eDA7fM0ePyI',
#  '9TpLFzihviw',
#  'keICo6GJ0yM',
#  '1ImH0tqGuXQ',
#  'Kzwdqf2HIeg',
#  'pGLNVyuRgwI',
#  'DCkanQG6Iek',
#  'R2mKVD-LC94',
#  'Ap_HTQ4h7GU',
#  'Wmi9XJD59Us',
#  'LP5raSGSCd8',
#  'EbfW4V6fUh0',
#  'sAubE9aVbGY',
#  'ZC1OupAs0zo',
#  'DcRCQ0Z90lA',
#  'iid_tOLz3vA']

# %%
#get video information
def get_videos_info(video_ids):
    video_data=[]

    for video_id in video_ids:
        request=youtube.videos().list(
            part="snippet,ContentDetails,statistics",
            id=video_id
        )
        response=request.execute()

        for item in response["items"]:
                data=dict(Channel_Name=item['snippet']['channelTitle'],
                        channel_Id=item['snippet']['channelId'],
                        video_Id=item['id'],
                        Title=item['snippet']['title'],
                        Tags=item.get('tags'),
                        Thumbnail=item['snippet']['thumbnails'],
                        Description=item.get('description'),
                        published_Date=item['snippet']['publishedAt'],
                        Duration=item['contentDetails']['duration'],
                        views=item.get('viewCount'),
                        comments=item.get('commentCount'),
                        Favorite_count=item['statistics']['favoriteCount'],
                        Definition=item['contentDetails']['definition'],
                        caption_status=item['contentDetails']['caption']
                        )
                video_data.append(data)
        return video_data

# %%
video_details=get_videos_info(video_Ids)

# %%
len(video_details)
# Out:
# 1

# %%
def get_comment_info(video_ids):
                Comment_data=[]
                try:
                        for video_id in video_ids:
                          request=youtube.commentThreads().list(
                                                part="snippet",
                                                videoId=video_id,
                                                maxResults=50
                                                )
                        response=request.execute()

                        for item in response['items']:
                            data=dict(Comment_Id=item['snippet']['topLevelComment']['id'],
                                  video_Id=item['snippet']['topLevelComment']['snippet']['videoId'],
                                  Comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                                  Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                                  Comment_published=item['snippet']['topLevelComment']['snippet']['publishedAt'])
                        
                        Comment_data.append(data)
                                                                
                except:
                        pass
                return Comment_data

# %%
Comment_details=get_comment_info(video_Ids)

# %%
Comment_details
# Out:
# [{'Comment_Id': 'UgyUbsjlLAf1QSaGdxJ4AaABAg',
#   'video_Id': 'iid_tOLz3vA',
#   'Comment_Text': 'Super',
#   'Comment_Author': '@keerthirajan4138',
#   'Comment_published': '2017-08-14T15:22:23Z'}]

# %%
# get_playlist_details
def get_playlist_details(channel_id):
    next_page_token=None
    All_data=[]
    while True:

        request=youtube.playlists().list(
                part='snippet,contentDetails',
                channelId=channel_id,
                maxResults=50,
                pageToken=next_page_token
                
            )       
        response=request.execute()

        for item in response['items']:
            data=dict(playlist_Id=item['id'],
                    Title=item['snippet']['title'],
                    channel_Id=item['snippet']['channelId'],
                    channel_Name=item['snippet']['channelTitle'],
                    publishedAt=item['snippet']['publishedAt'],
                    video_Count=item['contentDetails']['itemCount'])
            All_data.append(data)

        next_page_token=response.get('nextPageToken')
        if next_page_token is None:
            break
    return All_data

# %%
playlist_details=get_playlist_details('UCY6KjrDBN_tIRFT_QNqQbRQ')

# %%
len(playlist_details)
# Out:
# 54

# %%
#upload to monogodb
client=pymongo.MongoClient("mongodb+srv://susilapriyadharshini2:guviproject@cluster0.m9tdsja.mongodb.net/?retryWrites=true&w=majority")
db=client["youtube_data"]

# %%
def channel_details(channel_id):
      ch_details= get_Channel_info(channel_id) 
      pl_details=get_playlist_details(channel_id)
      vi_ids= get_videos_ids(channel_id)
      vi_details=get_videos_info(vi_ids)
      com_details=get_comment_info(vi_ids)

      coll1=db["channel_details"]
      coll1.insert_one({"channel_information":ch_details,"playlist_information":pl_details,
                        "video_information":vi_details,"Comment_information":com_details})
      
      return"upload completed successfully"

# %%
insert=channel_details("UgyUbsjlLAf1QSaGdxJ4AaABAg")
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# c:\Users\santh\Downloads\project\youtubetest.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/santh/Downloads/project/youtubetest.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> insert=channel_details("UC5cY198GU1MQMIPJgMkCJ_Q")
#
# c:\Users\santh\Downloads\project\youtubetest.ipynb Cell 20 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/santh/Downloads/project/youtubetest.ipynb#X25sZmlsZQ%3D%3D?line=5'>6</a> com_details=get_comment_info(vi_ids)
#       <a href='vscode-notebook-cell:/c%3A/Users/santh/Downloads/project/youtubetest.ipynb#X25sZmlsZQ%3D%3D?line=7'>8</a> coll1=db["channel_details"]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/santh/Downloads/project/youtubetest.ipynb#X25sZmlsZQ%3D%3D?line=8'>9</a> coll1.insert_one({"channel_information":ch_details,"playlist_information":pl_details,
#      <a href='vscode-notebook-cell:/c%3A/Users/santh/Downloads/project/youtubetest.ipynb#X25sZmlsZQ%3D%3D?line=9'>10</a>                   "video_information":vi_details,"Comment_information":com_details})
#      <a href='vscode-notebook-cell:/c%3A/Users/santh/Downloads/project/youtubetest.ipynb#X25sZmlsZQ%3D%3D?line=11'>12</a> return"upload completed successfully"
#
# File c:\Users\santh\Downloads\project\.venv\Lib\site-packages\pymongo\collection.py:669, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     665     document["_id"] = ObjectId()  # type: ignore[index]
#     667 write_concern = self._write_concern_for(session)
#     668 return InsertOneResult(
# --> 669     self._insert_one(
#     670         document,
#     671         ordered=True,
#     672         write_concern=write_concern,
#     673         op_id=None,
#     674         bypass_doc_val=bypass_document_validation,
#     675         session=session,
#     676         comment=comment,
#     677     ),
#     678     write_concern.acknowledged,
#     679 )
#
# File c:\Users\santh\Downloads\project\.venv\Lib\site-packages\pymongo\collection.py:609, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     597     result = conn.command(
#     598         self.__database.name,
#     599         command,
#    (...)
#     604         retryable_write=retryable_write,
#     605     )
#     607     _check_write_command_response(result)
# --> 609 self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     611 if not isinstance(doc, RawBSONDocument):
#     612     return doc.get("_id")
#
# File c:\Users\santh\Downloads\project\.venv\Lib\site-packages\pymongo\mongo_client.py:1522, in MongoClient._retryable_write(self, retryable, func, session, bulk)
#    1502 def _retryable_write(
#    1503     self,
#    1504     retryable: bool,
#    (...)
#    1507     bulk: Optional[_Bulk] = None,
#    1508 ) -> T:
#    1509     """Execute an operation with consecutive retries if possible
#    1510
#    1511     Returns func()'s return value on success. On error retries the same
#    (...)
#    1520       - `bulk`: bulk abstraction to execute operations in bulk, defaults to None
#    1521     """
# -> 1522     with self._tmp_session(session) as s:
#    1523         return self._retry_with_session(retryable, func, s, bulk)
#
# File C:\Program Files\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\santh\Downloads\project\.venv\Lib\site-packages\pymongo\mongo_client.py:1840, in MongoClient._tmp_session(self, session, close)
#    1837     yield session
#    1838     return
# -> 1840 s = self._ensure_session(session)
#    1841 if s:
#    1842     try:
#
# File c:\Users\santh\Downloads\project\.venv\Lib\site-packages\pymongo\mongo_client.py:1823, in MongoClient._ensure_session(self, session)
#    1818     return session
#    1820 try:
#    1821     # Don't make implicit sessions causally consistent. Applications
#    1822     # should always opt-in.
# -> 1823     return self.__start_session(True, causal_consistency=False)
#    1824 except (ConfigurationError, InvalidOperation):
#    1825     # Sessions not supported.
#    1826     return None
#
# File c:\Users\santh\Downloads\project\.venv\Lib\site-packages\pymongo\mongo_client.py:1766, in MongoClient.__start_session(self, implicit, **kwargs)
#    1763 def __start_session(self, implicit: bool, **kwargs: Any) -> ClientSession:
#    1764     # Raises ConfigurationError if sessions are not supported.
#    1765     if implicit:
# -> 1766         self._topology._check_implicit_session_support()
#    1767         server_session: Union[_EmptyServerSession, _ServerSession] = _EmptyServerSession()
#    1768     else:
#
# File c:\Users\santh\Downloads\project\.venv\Lib\site-packages\pymongo\topology.py:573, in Topology._check_implicit_session_support(self)
#     571 def _check_implicit_session_support(self) -> None:
#     572     with self._lock:
# --> 573         self._check_session_support()
#
# File c:\Users\santh\Downloads\project\.venv\Lib\site-packages\pymongo\topology.py:589, in Topology._check_session_support(self)
#     585         self._select_servers_loop(
#     586             any_server_selector, self.get_server_selection_timeout(), None
#     587         )
#     588 elif not self._description.readable_servers:
# --> 589     self._select_servers_loop(
#     590         readable_server_selector, self.get_server_selection_timeout(), None
#     591     )
#     593 session_timeout = self._description.logical_session_timeout_minutes
#     594 if session_timeout is None:
#
# File c:\Users\santh\Downloads\project\.venv\Lib\site-packages\pymongo\topology.py:259, in Topology._select_servers_loop(self, selector, timeout, address)
#     256 while not server_descriptions:
#     257     # No suitable servers.
#     258     if timeout == 0 or now > end_time:
# --> 259         raise ServerSelectionTimeoutError(
#     260             f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     261         )
#     263     self._ensure_opened()
#     264     self._request_check_all()
#
# ServerSelectionTimeoutError: SSL handshake failed: ac-tkz6ns9-shard-00-00.m9tdsja.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-tkz6ns9-shard-00-01.m9tdsja.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-tkz6ns9-shard-00-02.m9tdsja.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 656c08f8724220c26610c9ab, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-tkz6ns9-shard-00-00.m9tdsja.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-tkz6ns9-shard-00-00.m9tdsja.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-tkz6ns9-shard-00-01.m9tdsja.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-tkz6ns9-shard-00-01.m9tdsja.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-tkz6ns9-shard-00-02.m9tdsja.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-tkz6ns9-shard-00-02.m9tdsja.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
insert
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\santh\Downloads\project\youtubetest.ipynb Cell 21 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/santh/Downloads/project/youtubetest.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> insert
#
# NameError: name 'insert' is not defined

# %%
# table creation for channels,playlist,videos,comments

mydb=psycopg2.connect(host="localhost",
                     user= "postgres",
                     password="priya",
                     database="youtube_data",
                     port="5432")
cursor=mydb.cursor()
try:
    create_query='''create table if not exists channels(Channel_Name varchar(100),primary key,
                                                        Channel_Id varchar(80),
                                                        subscribers bigint,
                                                        views bigint,
                                                        Total_videos int,
                                                        channel_Description text,
                                                        playlist_id varchar(80))'''
    cursor.execute(create_query)
    mydb.commit()
except:
    print("channels table already created")
# Out:
# channels table already created
